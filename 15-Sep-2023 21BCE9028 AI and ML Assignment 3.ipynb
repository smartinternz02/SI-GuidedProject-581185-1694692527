# %% [markdown]
# ## 15-SEP-2023 ASSIGNMENT 3
#
# ## NAME   : J.S.RITWHIK
# ## REG NO : 21BCE9028
#
# ##

# %% [markdown]
# ## 1. Importing the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. Importing the Dataset

# %%
df=pd.read_csv('Titanic-Dataset.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.shape
# Out:
# (891, 12)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# ## 3. Checking for Null values

# %%
df.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %% [markdown]
# ### Null values in Age column are replaced by mean of remaining Age values

# %%
df['Cabin'].fillna(df['Cabin'].mode()[0],inplace=True)
df['Embarked'].fillna(df['Embarked'].mode()[0],inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %% [markdown]
# ### Null values in Cabin and Embarked columns are replaced by their respective mode values as these two are categorical variables

# %% [markdown]
# ### Therefore all null values in all columns are replaced
#
# #

# %% [markdown]
# ## 4.Data Visualization

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
sns.barplot(x=df['Survived'],y=df['Fare'],ci=0)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Fare'>

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\jakka\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## 5.Outlier Detection

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
df['Parch'].value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
df['Embarked'].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
sns.boxplot(df['Age'])
# Out:
# C:\Users\jakka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(df['SibSp'])
# Out:
# C:\Users\jakka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SibSp'>

# %%
sns.boxplot(df['Pclass'])
# Out:
# C:\Users\jakka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Pclass'>

# %%
sns.boxplot(df['Fare'])
# Out:
# C:\Users\jakka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fare'>

# %% [markdown]
# ### From the above information we came to know that only columns Age, SibSp, Fare have outliers

# %% [markdown]
# ##  Age

# %%
# Boxplot of Age
sns.boxplot(df.Age)
# Out:
# C:\Users\jakka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
df.shape
# Out:
# (891, 12)

# %%
# Removing outliers of Age by IQR

q1 = df.Age.quantile(0.25)
q3 = df.Age.quantile(0.75)

# %%
IQR =q3-q1

# %%
upper_limit =q3+1.5*IQR
lower_limit =q1-1.5*IQR

# %%
df = df[df.Age<upper_limit]
df = df[df.Age>lower_limit]

# %%
sns.boxplot(df.Age)
# Out:
# C:\Users\jakka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
df.shape
# Out:
# (825, 12)

# %% [markdown]
# ##  SibSp

# %%
# Boxplot of SibSp
sns.boxplot(df.SibSp)
# Out:
# C:\Users\jakka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SibSp'>

# %%
df.shape
# Out:
# (825, 12)

# %%
# Removing outliers of Age by IQR

q1 = df.SibSp.quantile(0.25)
q3 = df.SibSp.quantile(0.75)

# %%
IQR =q3-q1

# %%
upper_limit =q3+1.5*IQR
lower_limit =q1-1.5*IQR

# %%
df = df[df.SibSp<upper_limit]
df = df[df.SibSp>lower_limit]

# %%
sns.boxplot(df.SibSp)
# Out:
# C:\Users\jakka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SibSp'>

# %%
df.shape
# Out:
# (786, 12)

# %% [markdown]
# ## Fare

# %%
# Boxplot of Fare
sns.boxplot(df.Fare)
# Out:
# C:\Users\jakka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fare'>

# %%
df.shape
# Out:
# (786, 12)

# %%
# Removing outliers of Age by IQR

q1 = df.Fare.quantile(0.25)
q3 = df.Fare.quantile(0.75)

# %%
IQR =q3-q1

# %%
upper_limit =q3+1.5*IQR
lower_limit =q1-1.5*IQR

# %%
df = df[df.Fare<upper_limit]
df = df[df.Fare>lower_limit]

# %%
sns.boxplot(df.Fare)
# Out:
# C:\Users\jakka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fare'>

# %%
df.shape
# Out:
# (684, 12)

# %% [markdown]
# ## 6. Splitting Dependent and Independent Variables

# %% [raw]
# PassengerId, Survived, Pclass, Name, Sex, Age, SibSp ,Parch, Ticket, Fare, Cabin, Embarked
#
# Form all columnns in dataframe we have to divde them in dependent and independent
# Dependent column is Survived.
# Some columns are not used for prediction of dependent column Survived so we have to remove some columns and remaining columns are placed in independent variable

# %%
x = df[['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']] # independent variable
y = df['Survived']                                               # dependent variable

# %%
x
# Out:
#      Pclass     Sex        Age  SibSp  Parch     Fare Embarked
# 0         3    male  22.000000      1      0   7.2500        S
# 2         3  female  26.000000      0      0   7.9250        S
# 3         1  female  35.000000      1      0  53.1000        S
# 4         3    male  35.000000      0      0   8.0500        S
# 5         3    male  29.699118      0      0   8.4583        Q
# ..      ...     ...        ...    ...    ...      ...      ...
# 886       2    male  27.000000      0      0  13.0000        S
# 887       1  female  19.000000      0      0  30.0000        S
# 888       3  female  29.699118      1      2  23.4500        S
# 889       1    male  26.000000      0      0  30.0000        C
# 890       3    male  32.000000      0      0   7.7500        Q
#
# [684 rows x 7 columns]

# %%
x.shape
# Out:
# (684, 7)

# %%
y
# Out:
# 0      0
# 2      1
# 3      1
# 4      0
# 5      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 684, dtype: int64

# %%
y.shape
# Out:
# (684,)

# %% [markdown]
# ## 7. Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %% [markdown]
# ### Label Encoding on Sex column

# %%
x['Sex']=le.fit_transform(x['Sex'])
# Out:
# C:\Users\jakka\AppData\Local\Temp\ipykernel_19252\2399500346.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Sex']=le.fit_transform(x['Sex'])

# %%
x.head()
# Out:
#    Pclass  Sex        Age  SibSp  Parch     Fare Embarked
# 0       3    1  22.000000      1      0   7.2500        S
# 2       3    0  26.000000      0      0   7.9250        S
# 3       1    0  35.000000      1      0  53.1000        S
# 4       3    1  35.000000      0      0   8.0500        S
# 5       3    1  29.699118      0      0   8.4583        Q

# %% [markdown]
# ### Label Encoding on Embarked column

# %%
x['Embarked']=le.fit_transform(x['Embarked'])
# Out:
# C:\Users\jakka\AppData\Local\Temp\ipykernel_19252\2142337331.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Embarked']=le.fit_transform(x['Embarked'])

# %%
x.head()
# Out:
#    Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0       3    1  22.000000      1      0   7.2500         2
# 2       3    0  26.000000      0      0   7.9250         2
# 3       1    0  35.000000      1      0  53.1000         2
# 4       3    1  35.000000      0      0   8.0500         2
# 5       3    1  29.699118      0      0   8.4583         1

# %% [markdown]
# ### One Hot Encoding on Embarked Column (Alternative way of Label Encoding)

# %%
x.Embarked.value_counts()
# Out:
# S    516
# C    100
# Q     68
# Name: Embarked, dtype: int64

# %%
x.shape
# Out:
# (684, 7)

# %%
Embarked=pd.get_dummies(x['Embarked'])
Embarked
# Out:
#      C  Q  S
# 0    0  0  1
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# 5    0  1  0
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [684 rows x 3 columns]

# %%
Embarked=pd.get_dummies(x['Embarked'],drop_first=True)
Embarked
# Out:
#      Q  S
# 0    0  1
# 2    0  1
# 3    0  1
# 4    0  1
# 5    1  0
# ..  .. ..
# 886  0  1
# 887  0  1
# 888  0  1
# 889  0  0
# 890  1  0
#
# [684 rows x 2 columns]

# %%
x=pd.concat([x,Embarked],axis=1)

# %%
x
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare Embarked  Q  S
# 0         3    1  22.000000      1      0   7.2500        S  0  1
# 2         3    0  26.000000      0      0   7.9250        S  0  1
# 3         1    0  35.000000      1      0  53.1000        S  0  1
# 4         3    1  35.000000      0      0   8.0500        S  0  1
# 5         3    1  29.699118      0      0   8.4583        Q  1  0
# ..      ...  ...        ...    ...    ...      ...      ... .. ..
# 886       2    1  27.000000      0      0  13.0000        S  0  1
# 887       1    0  19.000000      0      0  30.0000        S  0  1
# 888       3    0  29.699118      1      2  23.4500        S  0  1
# 889       1    1  26.000000      0      0  30.0000        C  0  0
# 890       3    1  32.000000      0      0   7.7500        Q  1  0
#
# [684 rows x 9 columns]

# %%
# Drop Embarked Column

x.drop(['Embarked'],axis=1,inplace=True)

# %%
x.head()
# Out:
#    Pclass  Sex        Age  SibSp  Parch     Fare  Q  S
# 0       3    1  22.000000      1      0   7.2500  0  1
# 2       3    0  26.000000      0      0   7.9250  0  1
# 3       1    0  35.000000      1      0  53.1000  0  1
# 4       3    1  35.000000      0      0   8.0500  0  1
# 5       3    1  29.699118      0      0   8.4583  1  0

# %%
x.shape
# Out:
# (684, 8)

# %% [markdown]
# ## 8. Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler # it scales all values in range [0,1]

# %%
ms=MinMaxScaler()

# %%
x_scaled=pd.DataFrame(ms.fit_transform(x),columns=x.columns)
# no need to scale y because y values are 0 and 1 only.

# %%
x_scaled.head()
# Out:
#    Pclass  Sex       Age  SibSp  Parch      Fare  Embarked
# 0     1.0  1.0  0.372549    0.5    0.0  0.127193       1.0
# 1     1.0  0.0  0.450980    0.0    0.0  0.139035       1.0
# 2     0.0  0.0  0.627451    0.5    0.0  0.931579       1.0
# 3     1.0  1.0  0.627451    0.0    0.0  0.141228       1.0
# 4     1.0  1.0  0.523512    0.0    0.0  0.148391       0.5

# %% [markdown]
# ## 9. Splitting Data into Train and Test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=0)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (547, 7) (137, 7) (547,) (137,)
